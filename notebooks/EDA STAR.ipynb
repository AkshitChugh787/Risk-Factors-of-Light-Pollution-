# %%
import pandas as pd

# %%
df = pd.read_csv('star_type.csv')

# %%
df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
import matplotlib.pyplot as plt
import mplcyberpunk
plt.style.use('cyberpunk')
import numpy as np

# %%
import seaborn as sb
plt.figure(figsize=(12,7))
sb.regplot(x = 'Temperature (K)', y = 'Luminosity(L/Lo)', data = df,line_kws={"color": "hotpink"})
plt.show()

# %%
plt.figure(figsize=(12,7))
sb.regplot(x = 'Temperature (K)', y = 'Radius(R/Ro)', data = df,line_kws={"color": "hotpink"})
plt.show()

# %%
plt.figure(figsize=(12,7))
sb.regplot(x = 'Temperature (K)', y = 'Absolute magnitude(Mv)', data = df,line_kws={"color": "hotpink"})
plt.show()

# %%
plt.figure(figsize=(12,7))
sb.regplot(x = 'Luminosity(L/Lo)', y = 'Temperature (K)', data = df,line_kws={"color": "hotpink"})
plt.show()

# %%
plt.figure(figsize=(12,7))
sb.regplot(x = 'Luminosity(L/Lo)', y = 'Radius(R/Ro)', data = df,line_kws={"color": "hotpink"})
plt.show()

# %%
plt.figure(figsize=(12,7))
sb.regplot(x = 'Luminosity(L/Lo)', y = 'Absolute magnitude(Mv)', data = df,line_kws={"color": "hotpink"})
plt.show()

# %%
figure= plt.figure(figsize=(10,10))
sb.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
figure= plt.figure(figsize=(12,7))
ax = sb.boxplot(x="Star type", y="Temperature (K)", data=df,color="#21fff7")

# %%
figure= plt.figure(figsize=(12,7))
ax = sb.boxplot(x="Star type", y="Luminosity(L/Lo)", data=df,color="#21fff7")
